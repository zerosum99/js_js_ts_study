// %%
import pl from 'npm:nodejs-polars';
const fooSeries = pl.Series("foo", [1, 2, 3])
fooSeries.sum()
// Out:
// 6

// %%
const fooSeries1 = pl.Series("foo", [1, 2, 3])

// %%
fooSeries1.sum()
// Out:
// 6

// %%
console.dir(pl)
// Out:
// {
//   DataType: [Getter],
//   Field: [Getter],
//   TimeUnit: [Getter],
//   Expr: [Getter],
//   pl: {
//     Expr: [Function: _Expr] {
//       isExpr: [Function: isExpr],
//       deserialize: [Function: deserialize]
//     },
//     DataFrame: [Function: DataFrameConstructor] {
//       isDataFrame: [Function: isDataFrame],
//       deserialize: [Function: deserialize]
//     },
//     LazyDataFrame: [Function: _LazyDataFrame] {
//       deserialize: [Function: deserialize],
//       fromExternal: [Function: fromExternal]
//     },
//     Series: [Function: SeriesConstructor] {
//       isSeries: [Function: isSeries],
//       from: [Function: from],
//       of: [Function: of],
//       deserialize: [Function: deserialize]
//     },
//     Config: {
//       setUtf8Tables: [Function: setUtf8Tables],
//       setAsciiTables: [Function: setAsciiTables],
//       setTblWidthChars: [Function: setTblWidthChars],
//       setTblRows: [Function: setTblRows],
// ...

// %%
console.dir(pl.Series)
// Out:
// [Function: SeriesConstructor] {
//   isSeries: [Function: isSeries],
//   from: [Function: from],
//   of: [Function: of],
//   deserialize: [Function: deserialize]
// }

// %%
console.dir(fooSeries);
// Out:
// shape: (3,)
// Series: 'foo' [f64]
// [
// 	1.0
// 	2.0
// 	3.0
// ]
